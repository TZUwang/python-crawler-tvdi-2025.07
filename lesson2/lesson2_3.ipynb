# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests              #使用外部套件requests(連結internet,下載網頁)
from pprint import pprint    #從pprint這一odule找出pprint這一function

r = requests.get('https://api.github.com/events')
if r.status_code == 200:
    print("下載成功")
    pprint(r.text)  #要看是甚麼類型 利用print(type(r))
else:               #若上述不成立(status_code不等於200) 即執行else
    print("下載失敗")
# Out:
# 下載成功
# ('[{"id":"51913544661","type":"PushEvent","actor":{"id":108077148,"login":"YourivHDenHaag","display_login":"YourivHDenHaag","gravatar_id":"","url":"https://api.github.com/users/YourivHDenHaag","avatar_url":"https://avatars.githubusercontent.com/u/108077148?"},"repo":{"id":326605203,"name":"nl-design-system/denhaag","url":"https://api.github.com/repos/nl-design-system/denhaag"},"payload":{"repository_id":326605203,"push_id":25407855427,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"a073bb0785691bc094d13139c9d886806cf7c2f9","before":"cacd84e684750c803e82ad680888dd4c5a44855b","commits":[{"sha":"a073bb0785691bc094d13139c9d886806cf7c2f9","author":{"email":"admin@nldesignsystem.nl","name":"NL '
#  'Design System"},"message":"docs(release): design system '
# ...
